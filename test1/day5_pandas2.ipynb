# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(5,3),index=['a','b','c','f','h'],columns=['A','C','B'])
df
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# f  0.754445  0.854718  0.693150
# h  0.099797  0.365598  0.842251

# %%
df = df.reindex(index=['a','b','c','d','e','f','g','h'])
df
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# d       NaN       NaN       NaN
# e       NaN       NaN       NaN
# f  0.754445  0.854718  0.693150
# g       NaN       NaN       NaN
# h  0.099797  0.365598  0.842251

# %%
df.isnull().sum()
# Out:
# A    3
# C    3
# B    3
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# A    0.375
# C    0.375
# B    0.375
# dtype: float64

# %%
df.isnull().any()
# Out:
# A    True
# C    True
# B    True
# dtype: bool

# %%
df.fillna({'A':1},inplace=True)
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# d  1.000000       NaN       NaN
# e  1.000000       NaN       NaN
# f  0.754445  0.854718  0.693150
# g  1.000000       NaN       NaN
# h  0.099797  0.365598  0.842251

# %%
df.ffill()
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# d  1.000000  0.131528  0.462926
# e  1.000000  0.131528  0.462926
# f  0.754445  0.854718  0.693150
# g  1.000000  0.854718  0.693150
# h  0.099797  0.365598  0.842251

# %%
df.bfill()
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# d  1.000000  0.854718  0.693150
# e  1.000000  0.854718  0.693150
# f  0.754445  0.854718  0.693150
# g  1.000000  0.365598  0.842251
# h  0.099797  0.365598  0.842251

# %%
df.dropna()
# Out:
#           A         C         B
# a  0.722979  0.876278  0.532578
# b  0.427002  0.749806  0.296901
# c  0.020428  0.131528  0.462926
# f  0.754445  0.854718  0.693150
# h  0.099797  0.365598  0.842251

# %%
df = pd.read_excel('IPL.xlsx')
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df_year  = df.groupby('Year')
for year,group in df_year:
    print('year{}\n'.format(year))
    print(group)
# Out:
# year2014
#
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
# year2015
#
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804
# year2016
#
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
# year2017
#
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
df_year.get_group(2015)
# Out:
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804

# %%
df_year.agg({'Points':[np.max,np.mean]})
# Out:
#      Points
#         max    mean
# Year
# 2014    876  795.25
# 2015    812  769.50
# 2016    756  725.00
# 2017    788  739.00

# %%
df_year['Points'].agg([np.max])
# Out:
#       max
# Year
# 2014  876
# 2015  812
# 2016  756
# 2017  788

# %%
Zscore = lambda x: (x-x.mean())/x.std()
df['zs']=df_year['Points'].transform(Zscore)

# %%
df
# Out:
#       Team  Rank  Year  Points        zs
# 0   Riders     1  2014     876  0.923501
# 1   Riders     2  2015     789  0.299834
# 2   Devils     2  2014     863  0.774826
# 3   Devils     3  2015     673 -1.483796
# 4    Kings     3  2014     741 -0.620432
# 5    Kings     4  2015     812  0.653485
# 6    Kings     1  2016     756  0.707107
# 7    Kings     1  2017     788  0.707107
# 8   Riders     2  2016     694 -0.707107
# 9   Royals     4  2014     701 -1.077894
# 10  Royals     1  2015     804  0.530476
# 11  Riders     2  2017     690 -0.707107

# %%
df_team = df.groupby(by='Team')

# %%
tetsfun = lambda x:len(x)>3
df_team.filter(tetsfun)
# Out:
#       Team  Rank  Year  Points        zs
# 0   Riders     1  2014     876  0.923501
# 1   Riders     2  2015     789  0.299834
# 4    Kings     3  2014     741 -0.620432
# 5    Kings     4  2015     812  0.653485
# 6    Kings     1  2016     756  0.707107
# 7    Kings     1  2017     788  0.707107
# 8   Riders     2  2016     694 -0.707107
# 11  Riders     2  2017     690 -0.707107
