# %%
import pandas as pd

# %%
a = pd.Series(['a','b','c'],[2,2,3])
a
# Out:
# 2    a
# 2    b
# 3    c
# dtype: str

# %%
dict = {'a':1,'b':2,'cc':10}
a = pd.Series(dict)
a
# Out:
# a      1
# b      2
# cc    10
# dtype: int64

# %%
import numpy as np

# %%
a = np.array([1,2,2,4,5])
b1 = pd.Series(a,copy=True)
b2 = pd.Series(a)
print(b1)
a
# Out:
# 0    1
# 1    2
# 2    2
# 3    4
# 4    5
# dtype: int64
# array([1, 2, 2, 4, 5])

# %%
b2
# Out:
# 0    1
# 1    2
# 2    2
# 3    4
# 4    5
# dtype: int64

# %%
a[1]=100
a
# Out:
# array([  1, 100,   2,   4,   5])

# %%
b1
# Out:
# 0    1
# 1    2
# 2    2
# 3    4
# 4    5
# dtype: int64

# %%
b2
# Out:
# 0    1
# 1    2
# 2    2
# 3    4
# 4    5
# dtype: int64

# %%
p = pd.Series(a,index=[2,1,3,4,5])
p
# Out:
# 2      1
# 1    100
# 3      2
# 4      4
# 5      5
# dtype: int64

# %%
p.iloc[1]
# Out:
# np.int64(100)

# %%
p.loc[3]+=1
p
# Out:
# 2      1
# 1    100
# 3      3
# 4      4
# 5      5
# dtype: int64

# %%
p[2]
# Out:
# np.int64(1)

# %%
#dataframe
#列
dict_1 = {'s':[1,2,3,4],
          'e':[5,6,7,8],
          'm':[9,8,7,6],
          'mi':[1,1,1,1]}

data = pd.DataFrame(dict_1,['a','b','c','d'])
data
# Out:
#    s  e  m  mi
# a  1  5  9   1
# b  2  6  8   1
# c  3  7  7   1
# d  4  8  6   1

# %%
dict_2 = {'s':pd.Series([1,2,3,4],['a','b','c','d']),
          'e':pd.Series([5,6,7,8],['a','b','c','d']),
          'm':pd.Series([9,8,7,6],['a','b','c','d']),
          'mi':pd.Series([1,1,1,1],['a','b','c','d'])}
data = pd.DataFrame(dict_2)
data
# Out:
#    s  e  m  mi
# a  1  5  9   1
# b  2  6  8   1
# c  3  7  7   1
# d  4  8  6   1

# %%
a = np.random.rand(3,3)
data = pd.DataFrame(a,index=['a','b','c'],columns=['s','e','m'])
data
# Out:
#           s         e         m
# a  0.196780  0.293109  0.478038
# b  0.530943  0.188566  0.382885
# c  0.204945  0.507458  0.111482

# %%
data['s']
# Out:
# a    0.196780
# b    0.530943
# c    0.204945
# Name: s, dtype: float64

# %%
data[1:3]
# Out:
#           s         e         m
# b  0.530943  0.188566  0.382885
# c  0.204945  0.507458  0.111482

# %%
data.m
# Out:
# a    0.478038
# b    0.382885
# c    0.111482
# Name: m, dtype: float64

# %%
data.loc['a']
# Out:
# s    0.196780
# e    0.293109
# m    0.478038
# Name: a, dtype: float64

# %%
data.iloc[0]
# Out:
# s    0.196780
# e    0.293109
# m    0.478038
# Name: a, dtype: float64

# %%
data.loc['a','m']
# Out:
# np.float64(0.47803805864888993)

# %%
data.iloc[:2,:2]
# Out:
#           s         e
# a  0.196780  0.293109
# b  0.530943  0.188566

# %%
data.iloc[[0,2],[0,2]]
# Out:
#           s         m
# a  0.196780  0.478038
# c  0.204945  0.111482

# %%
#增加
data
# Out:
#           s         e         m
# a  0.196780  0.293109  0.478038
# b  0.530943  0.188566  0.382885
# c  0.204945  0.507458  0.111482

# %%
data['mi'] = np.array([1,1,1])
data
# Out:
#           s         e         m  mi
# a  0.196780  0.293109  0.478038   1
# b  0.530943  0.188566  0.382885   1
# c  0.204945  0.507458  0.111482   1

# %%
data['mi2'] = pd.Series([1,1,1],index=['a','b','c'])
data
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1

# %%
data1 = pd.DataFrame([[2,3,4,5,6],[1,5,7,3,2]],['d','e'],['s','e','m','mi','mi2'])
data1
# Out:
#    s  e  m  mi  mi2
# d  2  3  4   5    6
# e  1  5  7   3    2

# %%
data = pd.concat([data,data1],axis=0)
data
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1
# d  2.000000  3.000000  4.000000   5    6
# e  1.000000  5.000000  7.000000   3    2

# %%
data.drop(['e','d'],axis=0)
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1

# %%
data
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1
# d  2.000000  3.000000  4.000000   5    6
# e  1.000000  5.000000  7.000000   3    2

# %%
data.drop(['e'],axis=0,inplace=True)#直接删除

# %%
data
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1
# d  2.000000  3.000000  4.000000   5    6

# %%
data.drop(data.index[1])
# Out:
#           s         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# c  0.204945  0.507458  0.111482   1    1
# d  2.000000  3.000000  4.000000   5    6

# %%
data.values
# Out:
# array([[0.19678036, 0.293109  , 0.47803806, 1.        , 1.        ],
#        [0.53094272, 0.18856576, 0.38288456, 1.        , 1.        ],
#        [0.20494499, 0.50745755, 0.11148204, 1.        , 1.        ],
#        [2.        , 3.        , 4.        , 5.        , 6.        ]])

# %%
data.T
# Out:
#             a         b         c    d
# s    0.196780  0.530943  0.204945  2.0
# e    0.293109  0.188566  0.507458  3.0
# m    0.478038  0.382885  0.111482  4.0
# mi   1.000000  1.000000  1.000000  5.0
# mi2  1.000000  1.000000  1.000000  6.0

# %%
data.describe()
# Out:
#               s         e         m   mi   mi2
# count  4.000000  4.000000  4.000000  4.0  4.00
# mean   0.733167  0.997283  1.243101  2.0  2.25
# std    0.858776  1.341726  1.844483  2.0  2.50
# min    0.196780  0.188566  0.111482  1.0  1.00
# 25%    0.202904  0.266973  0.315034  1.0  1.00
# 50%    0.367944  0.400283  0.430461  1.0  1.00
# 75%    0.898207  1.130593  1.358529  2.0  2.25
# max    2.000000  3.000000  4.000000  5.0  6.00

# %%
data.sum()
# Out:
# s      2.932668
# e      3.989132
# m      4.972405
# mi     8.000000
# mi2    9.000000
# dtype: float64

# %%
#var std

# %%
data.rename(columns={'s':'A'},inplace=True)
data
# Out:
#           A         e         m  mi  mi2
# a  0.196780  0.293109  0.478038   1    1
# b  0.530943  0.188566  0.382885   1    1
# c  0.204945  0.507458  0.111482   1    1
# d  2.000000  3.000000  4.000000   5    6

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
data.columns
# Out:
# Index(['A', 'e', 'm', 'mi', 'mi2'], dtype='str')

# %%
df=data.reindex(index=['a', 'b', 'c'],columns=['A','B'])
df
# Out:
#           A   B
# a  0.196780 NaN
# b  0.530943 NaN
# c  0.204945 NaN

# %%
data.reindex(index=['a', 'b', 'c'],columns=['A','B'],fill_value=0)
# Out:
#           A  B
# a  0.196780  0
# b  0.530943  0
# c  0.204945  0

# %%
df.reset_index(inplace=True,drop=True)#不要增加abc列
df
# Out:
#           A   B
# 0  0.196780 NaN
# 1  0.530943 NaN
# 2  0.204945 NaN

# %%
df.sort_index()
# Out:
#           A   B
# 0  0.196780 NaN
# 1  0.530943 NaN
# 2  0.204945 NaN

# %%
df.sort_values(by='A',ascending=False)
# Out:
#           A   B
# 1  0.530943 NaN
# 2  0.204945 NaN
# 0  0.196780 NaN
